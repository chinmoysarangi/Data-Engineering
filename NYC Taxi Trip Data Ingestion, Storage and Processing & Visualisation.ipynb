# %%
import pandas as pd
import numpy as np
from datetime import datetime

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from scipy.stats import norm
import scipy.stats as stats
import pylab  

import warnings
warnings.filterwarnings('ignore')

# %%
#Reading local csv file with pandas
import pandas as pd
green_2015_data_path=(r'E:\Masters\Data Engineering\New York Cabs Datasets in csv\green_tripdata_2015-12.csv')
green_2015_data = pd.read_csv(green_2015_data_path, nrows=1000)
green_2015_data.head()
# Out:
#    VendorID lpep_pickup_datetime Lpep_dropoff_datetime Store_and_fwd_flag  \
# 0         2  2015-12-01 00:12:54   2015-12-01 00:18:18                  N
# 1         2  2015-12-01 00:48:19   2015-12-01 00:59:31                  N
# 2         2  2015-12-01 00:06:13   2015-12-01 00:20:40                  N
# 3         2  2015-12-01 00:43:38   2015-12-01 00:59:37                  N
# 4         2  2015-12-01 00:04:50   2015-12-01 00:09:40                  N
#
#    RateCodeID  Pickup_longitude  Pickup_latitude  Dropoff_longitude  \
# 0           1        -73.844681        40.721508         -73.836334
# 1           1        -73.807030        40.699657         -73.863670
# 2           1        -73.961815        40.805641         -73.925980
# 3           1        -73.945221        40.808384         -73.959587
# 4           1        -73.939018        40.805542         -73.943977
#
#    Dropoff_latitude  Passenger_count  ...  Fare_amount  Extra  MTA_tax  \
# 0         40.708878                1  ...          6.5    0.5      0.5
# 1         40.691143                1  ...         12.5    0.5      0.5
# 2         40.824123                2  ...         13.5    0.5      0.5
# 3         40.801357                1  ...         12.5    0.5      0.5
# 4         40.813740                5  ...          5.5    0.5      0.5
#
#    Tip_amount  Tolls_amount  Ehail_fee  improvement_surcharge  Total_amount  \
# 0        1.56           0.0        NaN                    0.3          9.36
# 1        2.00           0.0        NaN                    0.3         15.80
# 2        4.44           0.0        NaN                    0.3         19.24
# 3        2.76           0.0        NaN                    0.3         16.56
# 4        1.00           0.0        NaN                    0.3          7.80
#
#    Payment_type  Trip_type
# 0             1           1
# 1             1           1
# 2             1           1
# 3             1           1
# 4             1           1
#
# [5 rows x 21 columns]

# %%
#Initialising and storing the data in MongoDB server
import pymongo
from pymongo import MongoClient

client = MongoClient("mongodb://localhost:27017/")
mydb = client.Taxi_Database

collection_green = mydb.yellow_taxi_data
records_ = green_2015_data.to_dict(orient = 'records')
result = mydb.green_2015_data.insert_many(records_)

# %%
# %%time
#Accessing MongoDB data with pandas
green_md = pd.DataFrame(list(mydb.green_2015_data.find({})))
green_md.head()
# Out:
# Wall time: 22.9 ms
#    Dropoff_latitude  Dropoff_longitude  Ehail_fee  Extra  Fare_amount  \
# 0         40.708878         -73.836334        NaN    0.5          6.5
# 1         40.691143         -73.863670        NaN    0.5         12.5
# 2         40.824123         -73.925980        NaN    0.5         13.5
# 3         40.801357         -73.959587        NaN    0.5         12.5
# 4         40.813740         -73.943977        NaN    0.5          5.5
#
#   Lpep_dropoff_datetime  MTA_tax  Passenger_count  Payment_type  \
# 0   2015-12-01 00:18:18      0.5                1             1
# 1   2015-12-01 00:59:31      0.5                1             1
# 2   2015-12-01 00:20:40      0.5                2             1
# 3   2015-12-01 00:59:37      0.5                1             1
# 4   2015-12-01 00:09:40      0.5                5             1
#
#    Pickup_latitude  ...  Store_and_fwd_flag  Tip_amount Tolls_amount  \
# 0        40.721508  ...                   N        1.56          0.0
# 1        40.699657  ...                   N        2.00          0.0
# 2        40.805641  ...                   N        4.44          0.0
# 3        40.808384  ...                   N        2.76          0.0
# 4        40.805542  ...                   N        1.00          0.0
#
#    Total_amount  Trip_distance  Trip_type   VendorID  \
# 0          9.36           1.27           1         2
# 1         15.80           3.57           1         2
# 2         19.24           3.51           1         2
# 3         16.56           2.43           1         2
# 4          7.80           0.89           1         2
#
#                         _id  improvement_surcharge lpep_pickup_datetime
# 0  5d7bb6ca5732018bf60641f5                    0.3  2015-12-01 00:12:54
# 1  5d7bb6ca5732018bf60641f6                    0.3  2015-12-01 00:48:19
# 2  5d7bb6ca5732018bf60641f7                    0.3  2015-12-01 00:06:13
# 3  5d7bb6ca5732018bf60641f8                    0.3  2015-12-01 00:43:38
# 4  5d7bb6ca5732018bf60641f9                    0.3  2015-12-01 00:04:50
#
# [5 rows x 22 columns]

# %%
green_md.head()
# Out:
#    Dropoff_latitude  Dropoff_longitude  Ehail_fee  Extra  Fare_amount  \
# 0         40.708878         -73.836334        NaN    0.5          6.5
# 1         40.691143         -73.863670        NaN    0.5         12.5
# 2         40.824123         -73.925980        NaN    0.5         13.5
# 3         40.801357         -73.959587        NaN    0.5         12.5
# 4         40.813740         -73.943977        NaN    0.5          5.5
#
#   Lpep_dropoff_datetime  MTA_tax  Passenger_count  Payment_type  \
# 0   2015-12-01 00:18:18      0.5                1             1
# 1   2015-12-01 00:59:31      0.5                1             1
# 2   2015-12-01 00:20:40      0.5                2             1
# 3   2015-12-01 00:59:37      0.5                1             1
# 4   2015-12-01 00:09:40      0.5                5             1
#
#    Pickup_latitude  ...  Trip_distance  Trip_type  VendorID  \
# 0        40.721508  ...           1.27           1        2
# 1        40.699657  ...           3.57           1        2
# 2        40.805641  ...           3.51           1        2
# 3        40.808384  ...           2.43           1        2
# 4        40.805542  ...           0.89           1        2
#
#                         _id  improvement_surcharge  lpep_pickup_datetime  \
# 0  5d7bb6ca5732018bf60641f5                    0.3   2015-12-01 00:12:54
# 1  5d7bb6ca5732018bf60641f6                    0.3   2015-12-01 00:48:19
# 2  5d7bb6ca5732018bf60641f7                    0.3   2015-12-01 00:06:13
# 3  5d7bb6ca5732018bf60641f8                    0.3   2015-12-01 00:43:38
# 4  5d7bb6ca5732018bf60641f9                    0.3   2015-12-01 00:04:50
#
#    trip_time  trip_speed  pickup_day dropoff_day
# 0        5.0    0.254000     Tuesday     Tuesday
# 1       11.0    0.324545     Tuesday     Tuesday
# 2       14.0    0.250714     Tuesday     Tuesday
# 3       15.0    0.162000     Tuesday     Tuesday
# 4        4.0    0.222500     Tuesday     Tuesday
#
# [5 rows x 26 columns]

# %%
#Calculating trip time
green_md['lpep_pickup_datetime'] = pd.to_datetime(green_md['lpep_pickup_datetime'], infer_datetime_format=True)
green_md['Lpep_dropoff_datetime'] = pd.to_datetime(green_md['Lpep_dropoff_datetime'], infer_datetime_format=True)
tdelta = green_md['Lpep_dropoff_datetime'] - green_md['lpep_pickup_datetime']
green_md['trip_time'] = tdelta.astype('timedelta64[m]')

#Calculating average trip speed
green_md['trip_speed'] = green_md['Trip_distance'] / green_md['trip_time']

# %%
#Extracting pickup and dropoff day of week
green_md['pickup_day'] = green_md['lpep_pickup_datetime'].dt.weekday_name
green_md['dropoff_day'] = green_md['Lpep_dropoff_datetime'].dt.weekday_name

# %%
green_md.describe()
# Out:
#        Dropoff_latitude  Dropoff_longitude  Ehail_fee        Extra  \
# count       1000.000000        1000.000000        0.0  1000.000000
# mean          40.740990         -73.925605        NaN     0.483000
# std            0.058869           0.049278        NaN     0.103546
# min           40.576416         -74.160164        NaN    -0.500000
# 25%           40.695029         -73.955910        NaN     0.500000
# 50%           40.737049         -73.938236        NaN     0.500000
# 75%           40.781402         -73.899050        NaN     0.500000
# max           40.912746         -73.733376        NaN     0.500000
#
#        Fare_amount      MTA_tax  Passenger_count  Payment_type  \
# count  1000.000000  1000.000000      1000.000000   1000.000000
# mean     10.982500     0.483000         1.371000      1.563000
# std      26.659335     0.103546         1.071684      0.546195
# min      -9.000000    -0.500000         0.000000      1.000000
# 25%       5.500000     0.500000         1.000000      1.000000
# 50%       8.000000     0.500000         1.000000      2.000000
# 75%      12.500000     0.500000         1.000000      2.000000
# max     826.000000     0.500000         6.000000      5.000000
#
#        Pickup_latitude  Pickup_longitude   RateCodeID   Tip_amount  \
# count      1000.000000       1000.000000  1000.000000  1000.000000
# mean         40.701580        -73.856675     1.095000     0.941770
# std           1.289576          2.338299     0.606913     1.854485
# min           0.000000        -74.160164     1.000000     0.000000
# 25%          40.699361        -73.957304     1.000000     0.000000
# 50%          40.741735        -73.943676     1.000000     0.000000
# 75%          40.791748        -73.912016     1.000000     1.700000
# max          40.927448          0.000000     5.000000    36.000000
#
#        Tolls_amount  Total_amount  Trip_distance   Trip_type      VendorID  \
# count   1000.000000   1000.000000    1000.000000  1000.000000  1000.000000
# mean       0.055400     13.236070       2.665120     1.022000     1.805000
# std        0.551499     26.826616       5.570901     0.146757     0.396399
# min        0.000000    -10.300000       0.000000     1.000000     1.000000
# 25%        0.000000      7.300000       0.980000     1.000000     2.000000
# 50%        0.000000     10.300000       1.800000     1.000000     2.000000
# 75%        0.000000     15.300000       3.232500     1.000000     2.000000
# max        5.540000    827.300000     162.290000     2.000000     2.000000
#
#        improvement_surcharge    trip_time  trip_speed
# count            1000.000000  1000.000000  992.000000
# mean                0.290400    17.502000         inf
# std                 0.060758   109.124141         NaN
# min                -0.300000     0.000000    0.000000
# 25%                 0.300000     4.000000    0.210000
# 50%                 0.300000     7.000000    0.254083
# 75%                 0.300000    12.000000    0.316167
# max                 0.300000  1438.000000         inf

# %%
#Plot Trip Distance 
fig, axs = plt.subplots(1,2)
fig.set_size_inches(9, 3)
fig.subplots_adjust(wspace=.5)

axs[0].hist(green_md['Trip_distance'],bins=100);
axs[0].set_title('Histograpm of Trip Distance, 100 records')
axs[0].set_xlabel('Distance (mile)')
axs[0].set_ylabel('Number of records')

axs[1].hist(green_md['Trip_distance'],bins=500);
axs[1].set_title('Histograpm of Trip Distance, 500 records')
axs[1].set_xlabel('Distance (mile)')
axs[1].set_ylabel('Number of records');

# %%
# %%time
#Plotting all Pickup points Google Maps
from bokeh.io import output_file, show
from bokeh.models import ColumnDataSource, GMapOptions
from bokeh.plotting import gmap
from bokeh.models.tools import HoverTool

output_file("first_gmap.html")

map_options = GMapOptions(lat = 40.785091, lng = -73.968285, map_type = "roadmap", zoom = 10)
bokeh_plot = gmap("AIzaSyBJ0-xYKaENIolaFj9HH85a8s09ugqWxjA", map_options, title = "NYC Taxi Pick-up Locations")

source2 = ColumnDataSource(
    data = dict(lat = green_md.Pickup_latitude[:1000],
              lon = green_md.Pickup_longitude [:1000])
)

bokeh_plot.circle(x = "lon", y = "lat", size = 10,  color = "green", fill_alpha = 0.8, source = source2)

show(bokeh_plot)
# Out:
#   <div class="bk-root" id="ba76cc30-1055-42fc-ae6b-b18fe98be75d" data-root-id="5616"></div>
# Wall time: 166 ms

# %%
# %%time
#Plotting all Pickup points Google Maps
from bokeh.io import output_file, show
from bokeh.models import ColumnDataSource, GMapOptions
from bokeh.plotting import gmap
from bokeh.models.tools import HoverTool

output_file("first_gmap.html")

map_options = GMapOptions(lat = 40.785091, lng = -73.968285, map_type = "roadmap", zoom = 10)
bokeh_plot = gmap("AIzaSyBJ0-xYKaENIolaFj9HH85a8s09ugqWxjA", map_options, title = "NYC Taxi Drop-Off Locations")

source1 = ColumnDataSource(
    data = dict(lat = green_md.Dropoff_latitude[:1000],
              lon = green_md.Dropoff_longitude[:1000])
)

bokeh_plot.circle(x = "lon", y = "lat", size = 10,  color = "red", fill_alpha = 0.8, source = source1)

show(bokeh_plot)
# Out:
#   <div class="bk-root" id="5e949ea7-1ed0-4026-ba9a-af524e481afa" data-root-id="4647"></div>
# Wall time: 175 ms

# %%
# %%time
#Plotting Pickup and Dropoff on Google Maps
from bokeh.io import output_file, show
from bokeh.models import ColumnDataSource, GMapOptions
from bokeh.plotting import gmap
from bokeh.models.tools import HoverTool

output_file("first_gmap.html")

map_options = GMapOptions(lat = 40.785091, lng = -73.968285, map_type = "roadmap", zoom = 11)
bokeh_plot = gmap("AIzaSyBJ0-xYKaENIolaFj9HH85a8s09ugqWxjA", map_options, title = "Overall Pickup and Dropoff Locations")

source1 = ColumnDataSource(
    data = dict(lat = green_md.Dropoff_latitude[:1000],
              lon = green_md.Dropoff_longitude[:1000])
)

source2 = ColumnDataSource(
    data = dict(lat = green_md.Pickup_latitude[:1000],
              lon = green_md.Pickup_longitude [:1000])
)

bokeh_plot.circle(x = "lon", y = "lat", size = 10, color = "red", fill_alpha = 0.8, source = source1)
bokeh_plot.circle(x = "lon", y = "lat", size = 10,  color = "green", fill_alpha = 0.8, source = source2)

show(bokeh_plot)
# Out:
#   <div class="bk-root" id="652eac25-4493-4b0b-97ab-137d5ca0cd30" data-root-id="5038"></div>
# Wall time: 176 ms
